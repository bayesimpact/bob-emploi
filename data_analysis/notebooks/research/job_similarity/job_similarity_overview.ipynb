# %% [markdown]
# # Job similarity measure
#
# Author: Stephan <stephan@bayesimpact.org>
#
# Skip the run test because it would take too much time to create the necessary models.
#
# In our Pole Emploi web application we want to recommend similar jobs, when a user shows interest in a certain job. To achieve this we need a similarity measure between jobs, or at least job groups. One way of doing this is to use the hierarchy of the ROME ontology. However it would be nice to have a more gradual measure to get a ranking of related jobs.
#
# In this notebook I will compare a few different metrics for job similarity. Each metric can be evaluated visually in a 2D t-SNE embedding. Each circle in the graph represents a job, which is colored according its main ROME category. ROME has 14 main categories (e.g. AGRICULTURE ET PÊCHE, ESPACES NATURELS ET ESPACES VERTS, SOINS AUX ANIMAUX).
#
# Hover over the jobs in the graph to see its title.
#
# ## Vector space models
#
# The idea is that the relevance of a skill for a job might be proportional to the *distance* between the skill's wikipedia page and the job description. The *distance* between two pieces of text can be measured by obtaining a vector space representation of this text. The simplest approach is a simple [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model). But this results in a very sparse and high-dimensional space. I did some initial experiments using the [Tf-idf](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) representation of text, where words are normalized by their inverse document frequency (to silence words with a small information content). This vector space is still very sparse and high-dimensional. I did not get any reasonable looking results. Therefore I created a [Latent Semantic Analysis](https://en.wikipedia.org/wiki/Latent_semantic_analysis) with 400 topics.
#
# The creation of all these models and datastructures, used in this notebook, is explained in [another notebook](./gensim_model_creation.ipynb)
#
# **IMPORTANT**
#
# You don't have to re-create all the models and corpora, that would take hours. Simply download the zip file [from this folder](https://drive.google.com/open?id=1knoptQqGAoVjxRySr5j9nj7pb_ZJ6J4NLAcfqC5IMug), put it into this project's data folder, extract it and move it's files into a sub-folder named `wiki`

# %% [markdown]
# ### TODO
#
# * We saw that using overlap of activities does not cluster the jobs. There are too many different activities. But Paul saw that activities are hierarchically organized with a depth of four levels. Maybe we'll get a better signal when we use the activity categories

# %%
import os
import json
import itertools

import distance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import brewer2mpl
from gensim.models import tfidfmodel
from gensim.models import lsimodel
from gensim import corpora
from gensim import matutils
from sklearn import manifold
from bokeh import plotting
from bokeh import models
from bokeh import io

from bob_emploi.lib import read_data

io.output_notebook()

TOOLS="pan,wheel_zoom,box_zoom,reset,hover"

data_path = os.getenv('DATA_PATH')

# see gensim_model_creation.ipynb
dict_path = os.path.join(data_path, 'wiki/frwiki_wordids.txt.bz2')
tfidf_model_path = os.path.join(data_path, 'wiki/frwiki.tfidf_model')
lsi_model_path = os.path.join(data_path, 'wiki/frwiki_lsi')
rome_path = os.path.join(data_path, 'rome/ficheMetierXml')
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4edc49ee-98ff-450b-acf0-c3875af99191">Loading BokehJS ...</span>
#     </div>

# %%
def extract_from_fiche_dict(fiche_dict):
    return {
         'code_rome': fiche_dict['code_rome'],
         'name': fiche_dict['intitule'],
         'description': fiche_dict['description'][0],
         'work_cond': fiche_dict['work_cond'][0],
         'activities': [activity['code_ogr'] for activity in fiche_dict['activities']],
         'skills': [skill['code_ogr'] for skill in fiche_dict['skills']],
         'work_env': [work_env['code_ogr'] for work_env in fiche_dict['work_env']]
    }

fiche_dicts = [read_data.fiche_extractor(fiche) 
               for fiche in read_data.load_fiches_from_xml(rome_path)]
jobs = [extract_from_fiche_dict(fiche_dict) for fiche_dict in fiche_dicts]

# %%
# the dictionary is the mapping from actual words to integer IDs
dictionary = corpora.Dictionary.load_from_text(dict_path)
# this model is used to transform new text into Tf-idf
tfidf_model = tfidfmodel.TfidfModel.load(tfidf_model_path)
# transforms new text from Tf-idf to the 400 dim dense LSI space
# which was created by using the Wikipedia as a training corpus
lsi_model = lsimodel.LsiModel.load(lsi_model_path)

tsne = manifold.TSNE(n_components=2, random_state=0)

# %%
def text2lsi(text):
    tokens = text.lower().split()
    bow = dictionary.doc2bow(tokens)
    return lsi_model[tfidf_model[bow]]

def gensim_kernel(job1, job2):
    '''! operates on LSI representation of job, not on job'''
    return matutils.cossim(job1, job2)

def superkernel(job1, job2):
    job_1_stuff = job1['work_env'] + job1['skills']
    job_2_stuff = job2['work_env'] + job2['skills']
    return distance.jaccard(job_1_stuff, job_2_stuff)

def workenv_overlap_kernel(job1, job2):
    return distance.jaccard(job1['work_env'], job2['work_env'])

def skill_overlap_kernel(job1, job2):
    return distance.jaccard(job1['skills'], job2['skills'])

def activity_overlap_kernel(job1, job2):
    return distance.jaccard(job1['activities'], job2['activities'])

def distance_matrix(objects, metric):
    res = [[metric(o1, o2) for o2 in objects] for o1 in objects]
    return np.matrix(res)

def plot_embedding(res, jobs, title):
    rome_categories = list(set([j['code_rome'][0] for j in jobs]))
    bmap = brewer2mpl.get_map('Set3', 'Qualitative', 12)
    colors = bmap.hex_colors + ['#7FDA3C', '#D34641']
    job_colors = [colors[rome_categories.index(j['code_rome'][0])] for j in jobs]    
    

    source = plotting.ColumnDataSource(
        data=dict(
            title= [j['code_rome'] + ': ' + j['name'] for j in jobs]
        )
    )
    
    vis_x = res[:, 0]
    vis_y = res[:, 1]    

    p = plotting.figure(title=title, tools=TOOLS)
    p.circle(vis_x, vis_y, radius=0.5, source=source,
             fill_color=job_colors,
             line_color=None, fill_alpha=0.5)

    hover = p.select(dict(type=models.HoverTool))
    hover.tooltips = [
        ("title", "@title")
    ]

    plotting.show(p)

# %% [markdown]
# ### Skill sets
#
# Use the jaccard distance between the set of skills associated with each job.

# %%
skill_overlap_dists = distance_matrix(jobs, skill_overlap_kernel)
skill_tsne_res = tsne.fit_transform(skill_overlap_dists) 
plot_embedding(skill_tsne_res, jobs, "skill sets jaccard distance")
# Out:
#     <div class="plotdiv" id="66a71875-4554-4d2e-b14a-726cbb91732a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("66a71875-4554-4d2e-b14a-726cbb91732a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '66a71875-4554-4d2e-b14a-726cbb91732a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e3202c43-99b0-4399-aefe-5e29e3df12f1":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"},"tooltips":[["title","@title"]]},"id":"b6070b4d-eef8-46ad-8f56-fc7b8b619cd6","type":"HoverTool"},{"attributes":{"data_source":{"id":"16ef6131-9d0f-4739-9bbb-beaaccc49994","type":"ColumnDataSource"},"glyph":{"id":"fc73c64f-6b16-40c9-93cf-18b6061cfcf1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},"selection_glyph":null},"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"},{"attributes":{},"id":"1628a711-8d5d-4d4e-bdd1-5facaea13d5d","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc73c64f-6b16-40c9-93cf-18b6061cfcf1","type":"Circle"},{"attributes":{"callback":null},"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"},{"attributes":{},"id":"354d499b-b188-4605-8a10-601b243dff0e","type":"BasicTicker"},{"attributes":{},"id":"c0b2c844-7a27-4973-998e-842696d14426","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"}],"left":[{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"}],"renderers":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"},{"id":"5c0520db-a420-4109-9371-3d65e0e26507","type":"Grid"},{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"},{"id":"c840f0a8-e53e-4d91-b54b-901752d72265","type":"Grid"},{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},{"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"}],"title":"skill sets jaccard distance","tool_events":{"id":"1628a711-8d5d-4d4e-bdd1-5facaea13d5d","type":"ToolEvents"},"tools":[{"id":"c0b24cde-854e-4cd6-a09c-d8215a06420d","type":"PanTool"},{"id":"2fdec7ea-0ab4-495e-a8bc-d90cdec18845","type":"WheelZoomTool"},{"id":"11205245-14ce-4925-94f0-93a8b73f5fb9","type":"BoxZoomTool"},{"id":"5dee0dbc-5fef-40c0-a179-1582b74b73d6","type":"ResetTool"},{"id":"b6070b4d-eef8-46ad-8f56-fc7b8b619cd6","type":"HoverTool"}],"x_range":{"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},"y_range":{"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"}},"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"788bcedf-c324-4f18-ac5e-38bae358ee3b","type":"BasicTicker"},{"attributes":{"overlay":{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},"plot":{"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"}},"id":"11205245-14ce-4925-94f0-93a8b73f5fb9","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["title","x","y","fill_color"],"data":{"fill_color":["#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#8DD3C7","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#CCEBC5","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#B3DE69","#BEBADA","#BEBADA","#BEBADA","#BE ...

# %% [markdown]
# ### Activity sets
#
# Use the jaccard distance between the set of activities associated with each job.

# %%
activity_overlap_dists = distance_matrix(jobs, activity_overlap_kernel)
act_tsne_res = tsne.fit_transform(activity_overlap_dists) 
plot_embedding(act_tsne_res, jobs, "activity sets jaccard distance")
# Out:
#     <div class="plotdiv" id="bd37e169-6389-4e32-826d-faba6b331b91"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd37e169-6389-4e32-826d-faba6b331b91");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd37e169-6389-4e32-826d-faba6b331b91' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fa90257f-eae0-48ed-b0b6-7ed2c42e4dcc":{"roots":{"references":[{"attributes":{"formatter":{"id":"02047507-9a76-4ae8-baf4-8bb4b5824564","type":"BasicTickFormatter"},"plot":{"id":"66fd1186-9003-42c5-b1c2-5064d7a9dfd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"0a08c083-ef62-4adb-8f55-85f32ea43412","type":"BasicTicker"}},"id":"a68c5aa4-2e17-4ad6-9096-17aa51ce810f","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"66fd1186-9003-42c5-b1c2-5064d7a9dfd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"0e4db37f-b515-4984-829c-d7c48721bad9","type":"BasicTicker"}},"id":"7d0f98a9-d8e4-44b5-96a9-9144e0ac5bed","type":"Grid"},{"attributes":{"data_source":{"id":"16ef6131-9d0f-4739-9bbb-beaaccc49994","type":"ColumnDataSource"},"glyph":{"id":"fc73c64f-6b16-40c9-93cf-18b6061cfcf1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},"selection_glyph":null},"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"69b98b6c-18ca-450c-8216-b390d15849f2","type":"DataRange1d"},{"attributes":{"callback":null},"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"},{"attributes":{},"id":"354d499b-b188-4605-8a10-601b243dff0e","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb222068-3903-4740-b143-73c136ee4b21","type":"Circle"},{"attributes":{"callback":null},"id":"5e433f0d-26b7-4306-88d7-22a0f503b55f","type":"DataRange1d"},{"attributes":{"plot":{"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"}},"id":"5dee0dbc-5fef-40c0-a179-1582b74b73d6","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},{"attributes":{},"id":"788bcedf-c324-4f18-ac5e-38bae358ee3b","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4ec5c2f3-162e-4bb2-a464-577b57e0b6be","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},{"attributes":{"below":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"}],"left":[{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"}],"renderers":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"},{"id":"5c0520db-a420-4109-9371-3d65e0e26507","type":"Grid"},{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"},{"id":"c840f0a8-e53e-4d91-b54b-901752d72265","type":"Grid"},{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},{"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"}],"title":"skill sets jaccard distance","tool_events":{"id":"1628a711-8d5d-4d4e-bdd1-5facaea13d5d","type":"ToolEvents"},"tools":[{"id":"c0b24cde-854e-4cd6-a09c-d8215a06420d","type":"PanTool"},{"id":"2fdec7ea-0ab4-495e-a8bc-d90cdec18845","type":"WheelZoomTool"},{"id":"11205245-14ce-4925-94f0-93a8b73f5fb9","type":"BoxZoomTool"},{"id":"5dee0dbc-5fef-40c0-a179-1582b74b73d6","type":"ResetTool"},{"id":"b6070b4d-eef8-46ad-8f56-fc7b8b619cd6","type":"HoverTool"}],"x_range":{"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},"y_range":{"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"}},"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"039711f2-f61c-4d46-a629-271 ...

# %% [markdown]
# ### Working environment sets
#
# Use the jaccard distance between the set of working environments associated with each job.

# %%
workenv_overlap_dists = distance_matrix(jobs, workenv_overlap_kernel)
workenv_tsne_res = tsne.fit_transform(workenv_overlap_dists) 
plot_embedding(workenv_tsne_res, jobs, "workenv sets jaccard distance")
# Out:
#     <div class="plotdiv" id="7b746f8d-025a-413c-a0b7-d5d80740919e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7b746f8d-025a-413c-a0b7-d5d80740919e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7b746f8d-025a-413c-a0b7-d5d80740919e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1361440e-3d8d-42fc-b0f5-205365d6e660":{"roots":{"references":[{"attributes":{"formatter":{"id":"02047507-9a76-4ae8-baf4-8bb4b5824564","type":"BasicTickFormatter"},"plot":{"id":"66fd1186-9003-42c5-b1c2-5064d7a9dfd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"0a08c083-ef62-4adb-8f55-85f32ea43412","type":"BasicTicker"}},"id":"a68c5aa4-2e17-4ad6-9096-17aa51ce810f","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"66fd1186-9003-42c5-b1c2-5064d7a9dfd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"0e4db37f-b515-4984-829c-d7c48721bad9","type":"BasicTicker"}},"id":"7d0f98a9-d8e4-44b5-96a9-9144e0ac5bed","type":"Grid"},{"attributes":{},"id":"b29791d4-958e-4fdb-904e-4734ade61bc7","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"}},"id":"f73f0b82-ec59-49e2-9920-bd0acf3dc151","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a0de7459-920e-4ac7-af96-2323ec498c16","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"69b98b6c-18ca-450c-8216-b390d15849f2","type":"DataRange1d"},{"attributes":{"plot":{"id":"66fd1186-9003-42c5-b1c2-5064d7a9dfd1","subtype":"Figure","type":"Plot"}},"id":"15bf72b6-eaa8-4c09-aff2-f6a5b966c8dd","type":"ResetTool"},{"attributes":{"callback":null},"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"},{"attributes":{},"id":"354d499b-b188-4605-8a10-601b243dff0e","type":"BasicTicker"},{"attributes":{"formatter":{"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe436095-56ab-4a50-8033-381ddf1af5e9","type":"BasicTicker"}},"id":"39a15e16-1552-4b32-8f80-eaf8171bdf13","type":"LinearAxis"},{"attributes":{"data_source":{"id":"65ca9a68-e3ed-4992-be26-ef13d4436dcb","type":"ColumnDataSource"},"glyph":{"id":"73ec700a-f85a-41df-b4b8-107f5cc7dd77","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f61307d9-5b24-44c5-a73b-64aead9842f5","type":"Circle"},"selection_glyph":null},"id":"a78a892a-92b1-4df8-8248-b97c5f731329","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb222068-3903-4740-b143-73c136ee4b21","type":"Circle"},{"attributes":{},"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"}},"id":"5dee0dbc-5fef-40c0-a179-1582b74b73d6","type":"ResetTool"},{"attributes":{"overlay":{"id":"a0de7459-920e-4ac7-af96-2323ec498c16","type":"BoxAnnotation"},"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"}},"id":"ebbfacc4-ab1f-4068-865c-11ff58e297b0","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"}},"id":"7d2af0ac-5d59-4205-b5ef-f5b70e9ca9cf","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"}],"left":[{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"}],"renderers":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"},{"id":"5c0520db-a420-4109-9371-3d65e0e26507","type":"Grid"},{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"},{"id":"c840f0a8-e53e-4d91-b54b-901752d72265","type":"Grid"},{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},{"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"}],"title":"skill sets jaccard dist ...

# %% [markdown]
# ### Working environment and skill sets combined

# %%
combined_overlap_dists = distance_matrix(jobs, superkernel)
combined_tsne_res = tsne.fit_transform(combined_overlap_dists) 
plot_embedding(combined_tsne_res, jobs, "workenv and skill sets jaccard distance")
# Out:
#     <div class="plotdiv" id="ac1f9ea5-7a12-4b07-865b-cbbb65fe14e3"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ac1f9ea5-7a12-4b07-865b-cbbb65fe14e3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ac1f9ea5-7a12-4b07-865b-cbbb65fe14e3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e4f17c74-0d54-49aa-bae5-5b97c69e77eb":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},{"attributes":{"plot":{"id":"6a92a3f3-2744-48cd-8602-5c271d719a88","subtype":"Figure","type":"Plot"}},"id":"2046a2e8-b19d-4e46-8053-5393f9a898cd","type":"ResetTool"},{"attributes":{},"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},{"attributes":{},"id":"0a1c096b-9278-4e25-b842-8eff1acc31a9","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a0de7459-920e-4ac7-af96-2323ec498c16","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},{"attributes":{},"id":"354d499b-b188-4605-8a10-601b243dff0e","type":"BasicTicker"},{"attributes":{"formatter":{"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe436095-56ab-4a50-8033-381ddf1af5e9","type":"BasicTicker"}},"id":"39a15e16-1552-4b32-8f80-eaf8171bdf13","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5decd74d-9227-4a12-a8ed-9032bdf2a9d5","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb222068-3903-4740-b143-73c136ee4b21","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"6a92a3f3-2744-48cd-8602-5c271d719a88","subtype":"Figure","type":"Plot"},"tooltips":[["title","@title"]]},"id":"364a54f8-2ee0-428a-ab1f-796da4d0fbaa","type":"HoverTool"},{"attributes":{"below":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"}],"left":[{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"}],"renderers":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"},{"id":"5c0520db-a420-4109-9371-3d65e0e26507","type":"Grid"},{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"},{"id":"c840f0a8-e53e-4d91-b54b-901752d72265","type":"Grid"},{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},{"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"}],"title":"skill sets jaccard distance","tool_events":{"id":"1628a711-8d5d-4d4e-bdd1-5facaea13d5d","type":"ToolEvents"},"tools":[{"id":"c0b24cde-854e-4cd6-a09c-d8215a06420d","type":"PanTool"},{"id":"2fdec7ea-0ab4-495e-a8bc-d90cdec18845","type":"WheelZoomTool"},{"id":"11205245-14ce-4925-94f0-93a8b73f5fb9","type":"BoxZoomTool"},{"id":"5dee0dbc-5fef-40c0-a179-1582b74b73d6","type":"ResetTool"},{"id":"b6070b4d-eef8-46ad-8f56-fc7b8b619cd6","type":"HoverTool"}],"x_range":{"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},"y_range":{"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"}},"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"039711f2-f61c-4d46-a629-2711fb3f74ea","type":"BasicTickFormatter"},{"attributes":{},"id":"f7e91ef9-ff19-4d46-9fd7-bd304d7c0e43","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"1850d4d0-1d2c-4875 ...

# %% [markdown]
# ## Vector space models
#
# I trained a vector space model on the french wikipedia. We can now measure semantic similarity between any two pieces of french text.
#
# ### job description similarity
#
# Use the description of a job from ROME to measure similarity

# %%
job_desc_lsi = [text2lsi(job['description']) for job in jobs]
desc_dists = distance_matrix(job_desc_lsi, gensim_kernel)
job_desc_tsne_res = tsne.fit_transform(desc_dists) 
plot_embedding(job_desc_tsne_res, jobs, "job description vector space distance")
# Out:
#     <div class="plotdiv" id="3c00a984-b3c5-4cfd-a697-5b590222c3fc"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3c00a984-b3c5-4cfd-a697-5b590222c3fc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3c00a984-b3c5-4cfd-a697-5b590222c3fc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"be68cf8d-047c-4829-8684-bc5cd50c611a":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},{"attributes":{"plot":{"id":"789033c9-6eb0-47b9-95c1-e7cb8b6c5269","subtype":"Figure","type":"Plot"}},"id":"5fad0b4f-812a-430e-bcf0-66073461586c","type":"PanTool"},{"attributes":{"plot":{"id":"6a92a3f3-2744-48cd-8602-5c271d719a88","subtype":"Figure","type":"Plot"}},"id":"2046a2e8-b19d-4e46-8053-5393f9a898cd","type":"ResetTool"},{"attributes":{"callback":null,"plot":{"id":"789033c9-6eb0-47b9-95c1-e7cb8b6c5269","subtype":"Figure","type":"Plot"},"tooltips":[["title","@title"]]},"id":"24b3fdd9-c0b2-4945-9bf1-b91c219a385c","type":"HoverTool"},{"attributes":{},"id":"0a1c096b-9278-4e25-b842-8eff1acc31a9","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"3968de0a-eef2-4175-94dd-9310bf0d1a63","type":"BoxAnnotation"},"plot":{"id":"789033c9-6eb0-47b9-95c1-e7cb8b6c5269","subtype":"Figure","type":"Plot"}},"id":"f7f709e5-8e85-4159-bb2d-50677681035b","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},{"attributes":{},"id":"354d499b-b188-4605-8a10-601b243dff0e","type":"BasicTicker"},{"attributes":{"formatter":{"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe436095-56ab-4a50-8033-381ddf1af5e9","type":"BasicTicker"}},"id":"39a15e16-1552-4b32-8f80-eaf8171bdf13","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5decd74d-9227-4a12-a8ed-9032bdf2a9d5","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb222068-3903-4740-b143-73c136ee4b21","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"6a92a3f3-2744-48cd-8602-5c271d719a88","subtype":"Figure","type":"Plot"},"tooltips":[["title","@title"]]},"id":"364a54f8-2ee0-428a-ab1f-796da4d0fbaa","type":"HoverTool"},{"attributes":{},"id":"bf55b082-7a3f-43d4-9bf3-1c0e00e926a6","type":"BasicTickFormatter"},{"attributes":{},"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},{"attributes":{},"id":"c84f83d7-447c-4475-818c-6aaa7e7a53eb","type":"BasicTicker"},{"attributes":{"below":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"}],"left":[{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"}],"renderers":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"},{"id":"5c0520db-a420-4109-9371-3d65e0e26507","type":"Grid"},{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"},{"id":"c840f0a8-e53e-4d91-b54b-901752d72265","type":"Grid"},{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},{"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"}],"title":"skill sets jaccard distance","tool_events":{"id":"1628a711-8d5d-4d4e-bdd1-5facaea13d5d","type":"ToolEvents"},"tools":[{"id":"c0b24cde-854e-4cd6-a09c-d8215a06420d","type":"PanTool"},{"id":"2fdec7ea-0ab4-495e-a8bc-d90cdec18845","type":"WheelZoomTool"},{"id":"11205245-14ce-4925-94f0-93a8b73f5fb9","type":"BoxZoomTool"},{"id":"5dee0dbc-5fef-40c0-a179-1582b74b73d6","type":"ResetTool"},{"id":"b6070b4d-eef8-46ad-8f56-fc7b8b619cd6","type":"HoverTool"}],"x_range":{"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},"y_range":{"id":"75e131ee-6bd3-4aa4-b94b-c0a59e20372d","type":"DataRange1d"}},"id":"f3238ef3-4ee7-44d9-9693-02fcd3fb9f04"," ...

# %% [markdown]
# ### job description + working conditions similarity
#
# Use the description of a job and the description of it's working conditions from ROME to measure similarity

# %%
job_desc_workenv_lsi = [text2lsi(job['description'] + ' ' + job['work_cond']) for job in jobs]
desc_dists = distance_matrix(job_desc_workenv_lsi, gensim_kernel)

job_desc_workenv_tsne_res = tsne.fit_transform(desc_dists) 
plot_embedding(job_desc_workenv_tsne_res, jobs, "job and work_env description vector space distance")
# Out:
#     <div class="plotdiv" id="82254dff-de30-4da6-92e6-3d980a2f5a5e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("82254dff-de30-4da6-92e6-3d980a2f5a5e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '82254dff-de30-4da6-92e6-3d980a2f5a5e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8d56ae98-594e-48d9-80b0-1f3d0be451e7":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d9396c5-181d-40e9-8fb8-941953db682d","type":"Circle"},{"attributes":{"plot":{"id":"789033c9-6eb0-47b9-95c1-e7cb8b6c5269","subtype":"Figure","type":"Plot"}},"id":"5fad0b4f-812a-430e-bcf0-66073461586c","type":"PanTool"},{"attributes":{"plot":{"id":"6a92a3f3-2744-48cd-8602-5c271d719a88","subtype":"Figure","type":"Plot"}},"id":"2046a2e8-b19d-4e46-8053-5393f9a898cd","type":"ResetTool"},{"attributes":{"plot":{"id":"f902922e-6f86-490b-89af-afb8a612e230","subtype":"Figure","type":"Plot"}},"id":"5654dcd8-f3b9-4903-8516-00002a0478dc","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id":"789033c9-6eb0-47b9-95c1-e7cb8b6c5269","subtype":"Figure","type":"Plot"},"tooltips":[["title","@title"]]},"id":"24b3fdd9-c0b2-4945-9bf1-b91c219a385c","type":"HoverTool"},{"attributes":{"plot":{"id":"66fd1186-9003-42c5-b1c2-5064d7a9dfd1","subtype":"Figure","type":"Plot"}},"id":"9442a0af-44e4-4cf4-86a1-826b7341a505","type":"WheelZoomTool"},{"attributes":{},"id":"0a1c096b-9278-4e25-b842-8eff1acc31a9","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"3968de0a-eef2-4175-94dd-9310bf0d1a63","type":"BoxAnnotation"},"plot":{"id":"789033c9-6eb0-47b9-95c1-e7cb8b6c5269","subtype":"Figure","type":"Plot"}},"id":"f7f709e5-8e85-4159-bb2d-50677681035b","type":"BoxZoomTool"},{"attributes":{},"id":"8ddf944c-4c75-49a2-ae28-04237b6203f4","type":"BasicTicker"},{"attributes":{"callback":null},"id":"9c94b82f-111e-48d7-ad20-efdb03e5460d","type":"DataRange1d"},{"attributes":{},"id":"354d499b-b188-4605-8a10-601b243dff0e","type":"BasicTicker"},{"attributes":{"formatter":{"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},"plot":{"id":"12ee618c-d9a6-409c-8c47-89630cdf9f9a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe436095-56ab-4a50-8033-381ddf1af5e9","type":"BasicTicker"}},"id":"39a15e16-1552-4b32-8f80-eaf8171bdf13","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5decd74d-9227-4a12-a8ed-9032bdf2a9d5","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb222068-3903-4740-b143-73c136ee4b21","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"6a92a3f3-2744-48cd-8602-5c271d719a88","subtype":"Figure","type":"Plot"},"tooltips":[["title","@title"]]},"id":"364a54f8-2ee0-428a-ab1f-796da4d0fbaa","type":"HoverTool"},{"attributes":{},"id":"bf55b082-7a3f-43d4-9bf3-1c0e00e926a6","type":"BasicTickFormatter"},{"attributes":{},"id":"df5cd8ec-1117-45b9-8773-7f990fe28417","type":"BasicTickFormatter"},{"attributes":{},"id":"c84f83d7-447c-4475-818c-6aaa7e7a53eb","type":"BasicTicker"},{"attributes":{"below":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"}],"left":[{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"}],"renderers":[{"id":"d4ff580f-48be-4c89-bc32-38f1b86c1457","type":"LinearAxis"},{"id":"5c0520db-a420-4109-9371-3d65e0e26507","type":"Grid"},{"id":"b678ff1c-f403-4746-8562-94357956011f","type":"LinearAxis"},{"id":"c840f0a8-e53e-4d91-b54b-901752d72265","type":"Grid"},{"id":"5cd6983a-66a6-4e4c-82a4-7030d8b3d689","type":"BoxAnnotation"},{"id":"5c14e98d-0e93-4b21-96a5-c1bd4885f1da","type":"GlyphRenderer"}],"title":"skill sets jaccard distance","tool_events":{"id":"1628a711-8d5d-4d4e-bdd1-5facaea13d5d","type":"ToolEvents"},"tools":[{"id":"c0b24cde-854e-4cd6-a09c-d8215a06420d","type":"PanTool"},{"id":"2fdec7ea-0ab4-495e-a8bc-d90cdec18845" ...

# %% [markdown]
# ## Conclusion
#
# * Seems like the vector space similarity measures pick up some structure that at least somehow correlates with the ROME categorization. I'm confident that we could dramatically improve this measure by getting longer descriptions of the jobs. Maybe find wikipedia articles for each of them. However a quick search showed that its not easy to find a wikipedia page for each job group.
# * Skill overlap looks much better than activity overlap
